# %%
import json
import pandas as pd
import plotly
import plotly.express as px
import numpy as np
end_user_consumption = open("End User Consumption.json") #open json file
data = json.load(end_user_consumption) #load json content

# %%
data
# Out:
# {'AL': {'Coal': '(4.3%)',
#   'Naturalgas': '(23.3%)',
#   'Petroleum': '(38.9%)',
#   'Renewableenergy': '(11.6%)',
#   'Electricity': '(21.9%)'},
#  'AK': {'Coal': '(1.2%)',
#   'Naturalgas': '(55.8%)',
#   'Petroleum': '(37.8%)',
#   'Renewableenergy': '(1.6%)',
#   'Electricity': '(3.5%)'},
#  'AZ': {'Coal': '(0.7%)',
#   'Naturalgas': '(10.7%)',
#   'Petroleum': '(58.0%)',
#   'Renewableenergy': '(3.3%)',
#   'Electricity': '(27.4%)'},
#  'AR': {'Coal': '(0.5%)',
#   'Naturalgas': '(26.2%)',
#   'Petroleum': '(43.0%)',
#   'Renewableenergy': '(9.3%)',
#   'Electricity': '(21.0%)'},
#  'CA': {'Coal': '(0.5%)',
#   'Naturalgas': '(24.7%)',
#   'Petroleum': '(57.7%)',
#   'Renewableenergy': '(3.4%)',
#   'Electricity': '(13.7%)'},
#  'CO': {'Coal': '(0.3%)',
#   'Naturalgas': '(34.2%)',
#   'Petroleum': '(46.1%)',
#   'Renewableenergy': '(2.3%)',
#   'Electricity': '(17.0%)'},
#  'CT': {'Coal': '(0.0%)',
#   'Naturalgas': '(25.0%)',
#   'Petroleum': '(55.3%)',
# ...

# %%
data.keys()
# Out:
# dict_keys(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'])

# %%
df = pd.DataFrame(data)
df

# fig = px.bar(df, x="State", y="Energy Sources", color="Percent", title="Energy Consumption")
# fig.show()
# Out:
#                       AL       AK       AZ       AR       CA       CO  \
# Coal              (4.3%)   (1.2%)   (0.7%)   (0.5%)   (0.5%)   (0.3%)
# Naturalgas       (23.3%)  (55.8%)  (10.7%)  (26.2%)  (24.7%)  (34.2%)
# Petroleum        (38.9%)  (37.8%)  (58.0%)  (43.0%)  (57.7%)  (46.1%)
# Renewableenergy  (11.6%)   (1.6%)   (3.3%)   (9.3%)   (3.4%)   (2.3%)
# Electricity      (21.9%)   (3.5%)  (27.4%)  (21.0%)  (13.7%)  (17.0%)
#
#                       CT       DC       DE       FL  ...       SD       TN  \
# Coal              (0.0%)   (0.0%)   (0.0%)   (0.4%)  ...   (1.0%)   (2.4%)
# Naturalgas       (25.0%)  (35.0%)  (28.5%)   (7.3%)  ...  (27.3%)  (19.8%)
# Petroleum        (55.3%)  (21.6%)  (51.8%)  (59.4%)  ...  (38.1%)  (49.4%)
# Renewableenergy   (2.9%)   (1.7%)   (1.1%)   (5.1%)  ...  (19.6%)   (5.2%)
# Electricity      (16.8%)  (41.6%)  (18.6%)  (27.7%)  ...  (14.0%)  (23.2%)
#
#                       TX       UT       VT       VA       WA       WV  \
# ...
